# %% [markdown]
# # Estructuras de datos.
#
# ## Primitivas
#
# - Enteros
# - Decimales
# - Cadenas de Caracteres
# - Booleanos
#
# ## No primitivas
#
# - Listas
# - Tuplas
# - Sets
# - Diccionarios

# %%
# Primitivas
a = 16

# %%
b='hola'

# %%
c=3.14

# %%
d=True

# %%
e=true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2ef3b7506700> in <module>
# ----> 1 e=true
#
# NameError: name 'true' is not defined

# %%
# No primitivas

# %%
x=[1,2,'tres']

# %%
x
# Out:
# [1, 2, 'tres']

# %%
y=(2,1,3.14)

# %%
y
# Out:
# (2, 1, 3.14)

# %%
z={ 'entero': 12, 'decimal' : 3.14 , 'string' : 'hola' , 'booleano' : False}

# %%
z
# Out:
# {'entero': 12, 'decimal': 3.14, 'string': 'hola', 'booleano': False}

# %% [markdown]
# ### Identificando el tipo de variables.
#
# `type()`

# %%
type(z)
# Out:
# dict

# %% [markdown]
# # Objetos
#
#
# ## Atributos
# Metadatos, atributos o propiedades (un punto y una palabra sin paréntesis):
#
# `X.atributo` 👉 Un atributo caracteriza al dato
#
#
# ## Metodos
# Funcionalidad o métodos (un punto y una palabra con paréntesis):
#
# `X.metodo()` 👉 Un método es algo que el dato puede hacer, por lo tanto al ejecutarlo le estamos pidiendo al dato que ejecute una acción

# %%
b
# Out:
# 'hola'

# %%
b.upper()
# Out:
# 'HOLA'

# %%
b.islower()
# Out:
# True

# %%
z
# Out:
# {'entero': 12, 'decimal': 3.14, 'string': 'hola', 'booleano': False}

# %%
z.values()
# Out:
# dict_values([12, 3.14, 'hola', False])

# %%
dir(z)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
z.__class__
# Out:
# dict

# %% [markdown]
# # Para pensar
#
# punteros y objetos

# %%
x=[1]

# %%
x
# Out:
# [1]

# %%
y=x

# %%
print(y,x)
# Out:
# [1] [1]

# %%
x.append(5)

# %%
print(y,x)
# Out:
# [1, 5] [1, 5]

# %%
x=5

# %%
print(y,x)
# Out:
# [1, 5] 5

# %% [markdown]
# # Expresiones y Operadores

# %%
x = 40
y = 12
  
add = x + y
sub = x - y
pro = x * y
div = x / y
  
print(add)
print(sub)
print(pro)
print(div)
# Out:
# 52
# 28
# 480
# 3.3333333333333335

# %%
a = 13
b = 12.0
  
c = a + int(b)
print(c)
# Out:
# 25

# %%
a = 13
b = 5
  
c = a / b
print(c)
# Out:
# 2.6

# %% [markdown]
# ## Operadores de Comparacion
#
# Evaluemos las siguientes expresiones:
#
# ```python
# a == b
#
# a != b
#
# a < b
#
# a > b
#
# a <= b
#
# a >= b
# ```

# %%
a
# Out:
# 16

# %%
b
# Out:
# 'hola'

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
b=8

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a >= b
# Out:
# True
